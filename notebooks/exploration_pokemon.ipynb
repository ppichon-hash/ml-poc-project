# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/pokemon_cards.csv")

# %%
df.shape

# %%
df.columns.tolist()

# %%
df.dtypes

# %%
df.head(10)

# %%
df.tail(10)

# %%
df.isnull().sum()

# %%
df.describe()

# %%
for col in df.select_dtypes(include="object").columns:
    print(f"{col} : {df[col].nunique()} valeurs uniques")
    print(df[col].value_counts().head(10))
    print("---")

# %%
df["target"].value_counts()

# %%
df[df["target"] == 1].head(10)

# %%
df[df["target"] == 0].head(10)

# %%
print("Prix minimum :", df["market_price"].min())
print("Prix maximum :", df["market_price"].max())
print("Prix moyen :", df["market_price"].mean().round(2))

# %%
df.nlargest(1, "market_price")

# %%
df.nsmallest(1, "market_price")
